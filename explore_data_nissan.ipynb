# %%
import numpy as np
import pandas as pd

# do chinh xac 2 so sau dau phay
pd.set_option("display.precision", 2)

# %% [markdown]
# # Daily report sales

# %%
df = pd.read_csv("nissan_renacar/MR_DAILYREPORT_SALES.csv")
df.head(20)
# Out:
#     No  AD_CLIENT_ID DEPT_CODE APPLIED_CHARGES_CLASS  PURPOSE_OF_USE_MR  \
# 0    1       1000002     3K3P1                    P2                  3
# 1    2       1000002     3K3P1                    P2                  3
# 2    3       1000002     3K3P1                    P2                  3
# 3    4       1000002     3K3P1                    P2                  3
# 4    5       1000002     3K3P1                    P2                  3
# 5    6       1000002     3K3P1                    P5                  3
# 6    7       1000002     3K3P1                    P7                  3
# 7    8       1000002     3K3P1                   PH2                  3
# 8    9       1000002     3K3P1                   PH2                  3
# 9   10       1000002     3K3S1                    C2                  3
# 10  11       1000002     3K3S1                    P2                  4
# 11  12       1000002     3K3S1                   PH2                  1
# ...

# %%
df.shape
# Out:
# (13531, 17)

# %%
df.columns
# Out:
# Index(['No', 'AD_CLIENT_ID', 'DEPT_CODE', 'APPLIED_CHARGES_CLASS',
#        'PURPOSE_OF_USE_MR', 'CONTRACT_ORG_CODE', 'CONTRACT_ORG_KBN',
#        'CONTRACT_TYPE', 'D_ID_RENTAL_KBN', 'RENTAL_TERM_KBN', 'YEAR', 'MONTH',
#        'DAY', 'PREVIOUS_MONTH_ADJ', 'COUNT', 'SALES_AMT', 'RENTAL_TIME'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13531 entries, 0 to 13530
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   No                     13531 non-null  int64
#  1   AD_CLIENT_ID           13531 non-null  int64
#  2   DEPT_CODE              13531 non-null  object
#  3   APPLIED_CHARGES_CLASS  13531 non-null  object
#  4   PURPOSE_OF_USE_MR      13531 non-null  int64
#  5   CONTRACT_ORG_CODE      13531 non-null  object
#  6   CONTRACT_ORG_KBN       13531 non-null  object
#  7   CONTRACT_TYPE          13531 non-null  object
#  8   D_ID_RENTAL_KBN        13531 non-null  int64
#  9   RENTAL_TERM_KBN        13531 non-null  object
#  10  YEAR                   13531 non-null  int64
#  11  MONTH                  13531 non-null  int64
#  12  DAY                    13531 non-null  int64
#  13  PREVIOUS_MONTH_ADJ     13531 non-null  int64
# ...

# %%
df.describe()
# Out:
#              No  AD_CLIENT_ID  PURPOSE_OF_USE_MR  D_ID_RENTAL_KBN     YEAR  \
# count  13531.00      1.35e+04           13531.00         13531.00  13531.0
# mean    6766.00      1.00e+06               2.16             6.32   2021.0
# std     3906.21      0.00e+00               1.25             1.71      0.0
# min        1.00      1.00e+06               1.00             1.00   2021.0
# 25%     3383.50      1.00e+06               1.00             7.00   2021.0
# 50%     6766.00      1.00e+06               3.00             7.00   2021.0
# 75%    10148.50      1.00e+06               3.00             7.00   2021.0
# max    13531.00      1.00e+06               7.00             7.00   2021.0
#
#          MONTH       DAY  PREVIOUS_MONTH_ADJ     COUNT  SALES_AMT  RENTAL_TIME
# count  13531.0  13531.00            13531.00  13531.00   13531.00     13531.00
# mean      10.0      3.67                0.27      1.30   19400.91        73.33
# ...

# %%
df["PURPOSE_OF_USE_MR"].value_counts()
# Out:
# 1    6544
# 3    5750
# 5     572
# 4     350
# 2     184
# 6      70
# 7      61
# Name: PURPOSE_OF_USE_MR, dtype: int64

# %%
df["D_ID_RENTAL_KBN"].value_counts()
# Out:
# 7    11510
# 1      863
# 4      606
# 3      322
# 2      160
# 5       70
# Name: D_ID_RENTAL_KBN, dtype: int64

# %%
df["YEAR"].value_counts()
# Out:
# 2021    13531
# Name: YEAR, dtype: int64

# %%
df["MONTH"].value_counts()
# Out:
# 10    13531
# Name: MONTH, dtype: int64

# %%
df["DAY"].value_counts()
# Out:
# 4    3043
# 3    2514
# 6    2355
# 5    2105
# 2    1795
# 1    1719
# Name: DAY, dtype: int64

# %%
df["PREVIOUS_MONTH_ADJ"].value_counts()
# Out:
# 0    13130
# 9      401
# Name: PREVIOUS_MONTH_ADJ, dtype: int64

# %%
df["COUNT"].value_counts()
# Out:
#  1     10635
#  2      1391
#  0       474
#  3       435
#  4       199
#  5       107
# -1        95
#  6        48
#  7        37
#  9        25
#  8        21
#  10       11
#  11       10
# -2         8
#  12        7
#  13        4
#  14        3
#  18        3
# -3         3
#  15        2
#  20        2
#  17        2
#  21        2
#  16        2
#  23        2
#  19        1
# -5         1
#  29        1
# Name: COUNT, dtype: int64

# %%
df["SALES_AMT"].value_counts()
# Out:
# 0         240
# 7225      148
# 5500      110
# 9000      105
# 3800      102
#          ...
# 75400       1
# 81705       1
# 272000      1
# 35980       1
# 12206       1
# Name: SALES_AMT, Length: 5014, dtype: int64

# %%
df["RENTAL_TIME"].value_counts()
# Out:
#  8      537
#  24     531
#  9      528
#  6      527
#  7      506
#        ...
#  300      1
# -308      1
# -316      1
#  324      1
# -357      1
# Name: RENTAL_TIME, Length: 697, dtype: int64

# %% [markdown]
# # Rent car service

# %%
df = pd.read_csv("nissan_renacar/NK_RENT_CAR_SERVICE.csv")
df.head(5)
# Out:
#    No  NK_RENT_CAR_SERVICE_ID  DESCRIPTION  AD_CLIENT_ID  AD_ORG_ID  \
# 0   1                 1001848          NaN       1000002          0
# 1   2                 1001849          NaN       1000002          0
# 2   3                 1001850          NaN       1000002          0
# 3   4                 1001851          NaN       1000002          0
# 4   5                 1001852          NaN       1000002          0
#
#               CREATED  CREATEDBY ISACTIVE             UPDATED  UPDATEDBY  ...  \
# 0  2014/12/18 0:21:23          0        Y  2014/12/18 0:21:23          0  ...
# 1  2014/12/18 0:21:23          0        Y  2014/12/18 0:21:23          0  ...
# 2  2014/12/18 0:21:23          0        Y  2014/12/18 0:21:23          0  ...
# 3  2014/12/18 0:21:23          0        Y  2014/12/18 0:21:23          0  ...
# 4  2014/12/18 0:21:23          0        Y  2014/12/18 0:21:23          0  ...
#
#   CLASSIFICATION_CORD_5 USERID            TOROKUYMD             HENKOYMD  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 99 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   No                        664 non-null    int64
#  1   NK_RENT_CAR_SERVICE_ID    664 non-null    int64
#  2   DESCRIPTION               0 non-null      float64
#  3   AD_CLIENT_ID              664 non-null    int64
#  4   AD_ORG_ID                 664 non-null    int64
#  5   CREATED                   664 non-null    object
#  6   CREATEDBY                 664 non-null    int64
#  7   ISACTIVE                  664 non-null    object
#  8   UPDATED                   664 non-null    object
#  9   UPDATEDBY                 664 non-null    int64
#  10  MAINTENANCE_KBN           664 non-null    object
#  11  RC_CREATED                664 non-null    object
#  12  RC_UPDATED                664 non-null    object
#  13  GENERATION                664 non-null    int64
# ...

# %%
df.shape
# Out:
# (664, 99)

# %%
df.columns
# Out:
# Index(['No', 'NK_RENT_CAR_SERVICE_ID', 'DESCRIPTION', 'AD_CLIENT_ID',
#        'AD_ORG_ID', 'CREATED', 'CREATEDBY', 'ISACTIVE', 'UPDATED', 'UPDATEDBY',
#        'MAINTENANCE_KBN', 'RC_CREATED', 'RC_UPDATED', 'GENERATION',
#        'CUSTOMER_KBN', 'CAR_KBN', 'OLD_CAR_KBN', 'CAR_NAME',
#        'BASIC_CHARGES_KBN', 'INSURANCE_CHARGES_KBN', 'DILLER_CHARGES_KBN',
#        'SEASON_CHARGES_KBN', 'ONE_WAY_KBN', 'ONE_WAY_CHARGES_KBN',
#        'EQUIPMENT1', 'EQUIPMENT2', 'EQUIPMENT3', 'EQUIPMENT4', 'EQUIPMENT5',
#        'LIMIT_CHARGES_KBN', 'SERVICE_KL_KBN', 'IMMUNITY_SUB_KBN',
#        'IMMUNITY_COMP', 'NAS_SUB_KBN', 'NAS_CHARGES_KBN', 'TAX_METHOD',
#        'NAS_N_SUB_PAS_COMP', 'NAS_N_SUB_PAS_COMP_KBN', 'NAS_N_SUB_OBJ_COMP',
#        'NAS_N_SUB_OBJ_COMP_KBN', 'NAS_SUB_PAS_COMP', 'NAS_SUB_PAS_COMP_KBN',
#        'NAS_SUB_OBJ_COMP', 'NAS_SUB_OBJ_COMP_KBN', 'DIS_MET_S_RENTAL',
#        'DIS_MET_L_T_RENTAL', 'DIS_RATE', 'DIS_ROUND_MET', 'DIS_ROUND_DIG',
# ...
